# %%
# Imported the dependencies of Pandas, JSON, and Pretty Print;
import requests
import json
from pprint import pprint
import numpy as np
import pandas as pd

# %%
def search_restaurants(set_num): 
# This function launches the request for all restaurants in Houston TX.

    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': 'Bearer xNlqIkDcllH9wywfX1HsS-szU7qm8U7frhfQxkWFuD1jwVjmHKbxRFVuVEmrryYZYNkSJ4dxbhnjuQbsW8sZlkaDNxCcQPIrzmk0iEWSR0xXzAVO74SULLPgb4JxXHYx',
    }
    url_params = { #parameters passed to the API
        "categories": 'Restaurants',
        "location":"Houston",
        "state": "Texas",
        #"price":[3, 4],
        'offset': offset_num, # We are going to iterate the offset
         "limit":50 # Maximum return of results per request (ref: API documentation).
     }

    response = requests.get(url, headers=headers, params=url_params).json()
    return response

# %%
if __name__ == "__main__":
    for offset_num in np.arange(50,1000,50): 
    # I want up to 1000 results (the limit), in steps of 50 results per request.
        try:
            output_json = search_restaurants(offset_num) # Executing the function defined above.
            print(offset_num) # Making sure each offset iteration is running
            
            #Use conditional statement to append results into a dataframe
            if offset_num == 50:
                business_df = pd.DataFrame.from_dict(output_json['businesses'])
            
            else:
                tempdf = pd.DataFrame.from_dict(output_json['businesses'])
                business_df = business_df.append(tempdf)

        except AttributeError:
            print("error at ", offset_num)
# Out:
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950

# %%
business_df.head()
# Out:
#                                      alias  \
# 0                            agora-houston
# 1                          paulies-houston
# 2         eddie-vs-prime-seafood-houston-4
# 3  sweet-paris-crêperie-and-café-houston-4
# 4                        gyro-king-houston
#
#                                           categories  \
# 0  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 1  [{'alias': 'sandwiches', 'title': 'Sandwiches'...
# 2  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 3  [{'alias': 'creperies', 'title': 'Creperies'},...
# 4  [{'alias': 'foodtrucks', 'title': 'Food Trucks...
#
#                                          coordinates   display_phone  \
# 0    {'latitude': 29.742984, 'longitude': -95.40258}  (713) 526-7212
# 1  {'latitude': 29.7428749, 'longitude': -95.4064...  (713) 807-7271
# 2  {'latitude': 29.7402734338612, 'longitude': -9...  (713) 874-1800
# 3  {'latitude': 29.717649, 'longitude': -95.4158516}  (713) 360-6266
# ...

# %%
business_df["price"].unique()
# Out:
# array(['$', '$$', '$$$', '$$$$', nan], dtype=object)

# %%
business_df.count()
# Out:
# alias            950
# categories       950
# coordinates      950
# display_phone    950
# distance         950
# id               950
# image_url        950
# is_closed        950
# location         950
# name             950
# phone            950
# price            910
# rating           950
# review_count     950
# transactions     950
# url              950
# dtype: int64

# %%
test = business_df["location"]
type(test)
# Out:
# pandas.core.series.Series

# %%
business_df["zipcode"] = np.zeros(len(business_df))

# %%
list_zips = []
i=0

for i in range(len(business_df)):
    zipcode = test.values[i]['zip_code']
    list_zips.append(zipcode)
    business_df["zipcode"][i] = zipcode
# Out:
# C:\Users\dbatt\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
business_df.head()
# Out:
#                                      alias  \
# 0                            agora-houston
# 1                          paulies-houston
# 2         eddie-vs-prime-seafood-houston-4
# 3  sweet-paris-crêperie-and-café-houston-4
# 4                        gyro-king-houston
#
#                                           categories  \
# 0  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 1  [{'alias': 'sandwiches', 'title': 'Sandwiches'...
# 2  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 3  [{'alias': 'creperies', 'title': 'Creperies'},...
# 4  [{'alias': 'foodtrucks', 'title': 'Food Trucks...
#
#                                          coordinates   display_phone  \
# 0    {'latitude': 29.742984, 'longitude': -95.40258}  (713) 526-7212
# 1  {'latitude': 29.7428749, 'longitude': -95.4064...  (713) 807-7271
# 2  {'latitude': 29.7402734338612, 'longitude': -9...  (713) 874-1800
# 3  {'latitude': 29.717649, 'longitude': -95.4158516}  (713) 360-6266
# ...

# %%
business_df.to_csv("yelp_data.csv", index = False)
